# %%
# ch4-2.py
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(module='sklearn*', action='ignore', category=DeprecationWarning)

# %%
# 데이터로드 (ch4-2(붓꽃데이터).csv : 데이터 원본 파일)
# encoding : 윈도우즈 환경에서의 한글 처리
# engine : python 3.6에서 한글이 포함된 파일이름 사용
rawData_org = pd.read_csv('datasets/국민건강정보/NHIS_OPEN_GJ_2017.csv', encoding='CP949', engine='python')

# %%
# 원본데이터의 튜플 수와 컬럼수 출력
rawData_org.shape
# Out:
# (1000000, 34)

# %%
# 의사결정트리에 사용할 속성리스트
feature_columns_to_use = ['성별코드', '연령대코드(5세단위)', '신장(5Cm단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)',
                    '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)', '트리글리세라이드', 'HDL콜레스테롤',
                    'LDL콜레스테롤', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '음주여부']

rawData = rawData_org[feature_columns_to_use]

# %%
# 속성값이 NULL인 튜플 제외
rawData = rawData.dropna()

# 인덱스 재설정
rawData.reset_index(inplace=True, drop=True)

# 원본데이터의 튜플 수와 컬럼수 출력
rawData.shape
# Out:
# (990910, 22)

# %%
import random as rd  # 샘플링을 위한 random 패키지 임포트

# 1) 샘플링을 통한 수량 축소
# 원본데이터 중 50,000개를 튜플만 샘플링
# len() : 데이터프레임의 크기를 구하는 함수
sample_idx = rd.sample(range(0, len(rawData)), 50000)

# 인덱스 값 정렬(오름차순)
sample_idx.sort()

sample_idx
# Out:
# [28,
#  92,
#  207,
#  228,
#  262,
#  265,
#  292,
#  299,
#  301,
#  318,
#  334,
#  360,
#  402,
#  424,
#  434,
#  436,
#  501,
#  549,
#  553,
#  567,
#  627,
#  641,
#  663,
#  677,
#  682,
#  694,
#  748,
#  775,
#  786,
#  789,
#  808,
#  864,
#  868,
#  872,
#  881,
#  894,
#  904,
#  926,
#  941,
#  1002,
#  1009,
#  1010,
#  1021,
#  1022,
#  1030,
#  1082,
#  1084,
#  1085,
#  1104,
#  1107,
#  1109,
#  1129,
#  1137,
#  1139,
#  1143,
#  1162,
#  1165,
#  1215,
#  1225,
#  1254,
#  1262,
#  1263,
#  1282,
#  1303,
#  1324,
#  1352,
#  1401,
#  1409,
#  1417,
#  1430,
#  1438,
#  1445,
#  1466,
#  1476,
#  1516,
#  1548,
#  1554,
#  1558,
#  1560,
#  1591,
#  1596,
#  1633,
#  1647,
#  1662,
#  1665,
#  1726,
#  1735,
#  1804,
#  1806,
#  1821,
#  1827,
#  1828,
#  1859,
#  1863,
#  1898,
#  1936,
#  1945,
#  1975,
#  1989,
#  1990,
#  2013,
#  2014,
#  2024,
#  2045,
#  2058,
#  2064,
#  2067,
#  2085,
#  2107,
#  2118,
#  2129,
#  2153,
#  2176,
#  2189,
#  2190,
#  2196,
#  2208,
#  2229,
#  2270,
#  2272,
#  2279,
#  2286,
#  2294,
#  2296,
#  2309,
#  2310,
#  2312,
#  2313,
#  2316,
#  2338,
#  2350,
#  2363,
#  2366,
#  2385,
#  2406,
#  2422,
#  2430,
#  2434,
#  2439,
#  2530,
#  2547,
#  2554,
#  2556,
#  2558,
#  2567,
#  2619,
#  2637,
#  2649,
#  2659,
#  2684,
#  2709,
#  2710,
#  17909,
#  17916,
#  17925,
#  17926,
#  17937,
#  17940,
#  17947,
#  17979,
#  18022,
#  18081,
#  18093,
#  18094,
#  18113,
#  18192,
#  18194,
#  18195,
#  18221,
#  18234,
#  18239,
#  18312,
#  18353,
#  18364,
#  18377,
#  18422,
#  18453,
#  18470,
#  18477,
#  18502,
#  18514,
#  18522,
#  18528,
#  18540,
#  18566,
#  18585,
#  18600,
#  18616,
#  18639,
#  18645,
#  18659,
#  18682,
#  18696,
#  18704,
#  18708,
#  18720,
#  18753,
#  18754,
#  18774,
#  18795,
#  18861,
#  18869,
#  18882,
#  ...]

# %%
# 샘플링 된 인덱스로 구성된 샘플 데이터프레임 생성
rawData_sample = rawData.loc[sample_idx]

rawData_sample.reset_index(inplace=True, drop=True) #  인덱스 재설정

# 첫 10개의 행만 출력
rawData_sample.head(10)
# Out:
#    성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0     1            7      175.0        75.0  76.0    0.3    0.4    1.0    1.0
# 1     1            7      170.0        70.0  80.0    1.2    1.0    1.0    1.0
# 2     2           10      145.0        45.0  79.0    1.2    1.2    1.0    1.0
# 3     2            6      155.0        50.0  69.1    0.8    1.5    1.0    1.0
# 4     2            8      165.0        55.0  71.0    1.5    1.2    1.0    1.0
# 5     2           12      155.0        60.0  78.0    1.0    0.9    2.0    1.0
# 6     1           10      170.0        80.0  82.8    1.0    1.0    1.0    1.0
# 7     2            5      155.0        55.0  68.0    1.0    1.0    1.0    1.0
# 8     1           10      170.0        80.0  93.0    1.2    1.2    1.0    1.0
# 9     2           10      165.0        45.0  65.0    0.7    0.8    1.0    1.0
#
#    수축기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0  131.0  ...     372.0      37.0     116.0  1.0      0.8        20.0
# 1  118.0  ...     316.0      25.0      96.0  1.0      0.9        23.0
# 2  120.0  ...     289.0      61.0     124.0  1.0      0.8        23.0
# 3  120.0  ...     116.0     103.0      74.0  1.0      0.8        19.0
# 4  119.0  ...      62.0      46.0      96.0  1.0      0.6        15.0
# 5  124.0  ...     198.0      39.0     217.0  1.0      0.8        23.0
# 6  130.0  ...     102.0      46.0     129.0  1.0      1.0        16.0
# 7  146.0  ...      63.0      81.0      80.0  1.0      0.6        17.0
# 8  128.0  ...     105.0      51.0     136.0  1.0      1.0        19.0
# 9  109.0  ...      46.0      71.0     113.0  1.0      0.6        16.0
#
#    (혈청지오티)ALT  감마지티피  흡연상태  음주여부
# 0        27.0   30.0   3.0   0.0
# 1        20.0   23.0   1.0   0.0
# 2        15.0   14.0   1.0   1.0
# 3        12.0   19.0   1.0   1.0
# 4         8.0   13.0   1.0   1.0
# 5        15.0   39.0   3.0   1.0
# 6        19.0   22.0   3.0   1.0
# 7        13.0   15.0   1.0   1.0
# 8        18.0   17.0   1.0   0.0
# 9         9.0    9.0   1.0   1.0
#
# [10 rows x 22 columns]

# %%
rawData_sample.shape
# Out:
# (50000, 22)

# %%
# nonnumeric 속성을 categrical 데이터로 변환
nonnumeric_columns = ['성별코드','음주여부']

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in nonnumeric_columns:
    rawData_sample[feature] = le.fit_transform(rawData_sample[feature])

# %%
# 소스 데이터프레임에서 분류(classification)을 위한 속성 집합
X = rawData_sample.loc[:, feature_columns_to_use[:-1]]  
y = rawData_sample.loc[:, '음주여부']  # 분류 클래스(class)

from sklearn.model_selection import train_test_split  # 분석모형 선택에 관련된 모듈
    
# 자동으로 데이터셋을 트레이닝셋과 테스트셋으로 분리해주는 함수로
# 트레이닝셋과 데이터셋의 비율을 7:3으로 세팅함
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Scikit-Learn 패키지 : 머신 러닝 교육 및 실무를 위한 패키지로 샘플 데이터셋,
# 다양한 기계학습 기법에 대한 함수 등을 포함하고 있음
import xgboost as xgb # xgboost 기법에 관련된 모듈

gbm = xgb.XGBClassifier(max_depth=4, n_estimators=300, learning_rate=0.05)

gbm

# %%
# RMSLE 계산하는 사용자정의 함수
from sklearn.metrics import make_scorer

def rmsle(predicted_values, actual_values) :
    # 넘파이로 배열 형태로 변환
    predicted_values = np.array(predicted_values)
    actual_values = np.array(actual_values)
    
    # 예측값과 실제값에 1을 더하고 로그를 씌움
    log_predict = np.log(predicted_values + 1)
    log_actual = np.log(actual_values + 1)
    
    # 위에서 계산한 예측값에서 실제값을 빼주고 제곱을 함
    difference = log_predict - log_actual
    # difference = (log_predict - log_actual) ** 2
    difference = np.square(difference)
    
    # 평균값 구함
    mean_difference = difference.mean()
    
    # 다시 루트를 씌움
    score = np.sqrt(mean_difference)
    
    return score

rmsle_scorer = make_scorer(rmsle)
rmsle_scorer
# Out:
# make_scorer(rmsle)

# %%
# KFold 교차검증
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# 트레이닝셋에 대한 KFold 교차검증 수
# %time score = cross_val_score(gbm, X_train, y_train, cv=k_fold, scoring=rmsle_scorer)
score = score.mean()

# 0에 근접할수록 좋은 데이터
print("Score= {0:.5f}".format(score))
# Out:
# Wall time: 1min 35s
# Score= 0.35952

# %%
# fit() : 트레이닝 데이터셋을 대상으로 의사결정트리 학습 진행
gbm.fit(X_train, y_train)

# tree.predict() 함수를 활용하여 의사결정트리를 대상으로 테스트셋을 예측
y_pred_tr = gbm.predict(X_test)

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(gbm.score(X_train, y_train)))
print("Test Set Score1 : {:.2f}".format(gbm.score(X_test, y_test)))
# Out:
# Train Set Score1 : 0.75
# Test Set Score1 : 0.74

# %%
from sklearn.metrics import accuracy_score  # 분류 정확도(classification accuracy)를 계산하는 모듈

# predict_proba() : 각 input 개체에 대한 예측클래스 확률 구함
y_pred_tr_prob = gbm.predict_proba(X_test)

# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.74

# %%
# 속성(feature) 별 중요도를 저장하는 데이터프레임 생성 
sel_feature = pd.DataFrame({'중요도' : gbm.feature_importances_}, index = feature_columns_to_use[:-1])

# 중요도의 내림차순으로 정렬
sel_feature.sort_values(by='중요도', ascending=False)
# Out:
#                   중요도
# 성별코드         0.369292
# 흡연상태         0.237057
# 연령대코드(5세단위)  0.102278
# 신장(5Cm단위)    0.081587
# 감마지티피        0.051577
# HDL콜레스테롤     0.026346
# (혈청지오티)ALT   0.016405
# 체중(5Kg 단위)   0.013215
# 이완기혈압        0.012134
# LDL콜레스테롤     0.010961
# (혈청지오티)AST   0.010936
# 식전혈당(공복혈당)   0.009525
# 트리글리세라이드     0.009450
# 혈청크레아티닌      0.009330
# 허리둘레         0.008424
# 요단백          0.007628
# 수축기혈압        0.007012
# 시력(우)        0.006997
# 시력(좌)        0.005739
# 청력(좌)        0.004107
# 청력(우)        0.000000

# %%
# 예측결과와 실제결과 비교
appData_anal_comp = pd.DataFrame(data={'actual': y_test, 'pred': y_pred_tr}, columns={'actual', 'pred'})
appData_anal_comp
# Out:
#        actual  pred
# 11841       1     0
# 19602       1     1
# 45519       1     1
# 25747       0     0
# 42642       1     1
# ...       ...   ...
# 38344       1     1
# 49984       0     1
# 32624       0     0
# 46437       1     0
# 35070       1     0
#
# [15000 rows x 2 columns]

# %%
# 예측 클래스와 클래스 예측확률을 X_test 데이터프레임에 붙임
X_test['음주여부'] = y_test
X_test['음주여부예측'] = y_pred_tr

X_test['음주확률'] = y_pred_tr_prob[:,1]

X_test
# Out:
# C:\Users\a\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\a\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\a\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#        성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  \
# 11841     1           10      160.0        55.0  71.0    1.5    1.0    1.0
# 19602     0            9      170.0        70.0  86.0    0.8    1.2    1.0
# 45519     0           12      165.0        60.0  80.0    0.1    1.5    1.0
# 25747     1            9      165.0        75.0  87.0    0.2    0.5    1.0
# 42642     1           10      140.0        40.0  60.0    0.4    0.6    1.0
# ...     ...          ...        ...         ...   ...    ...    ...    ...
# 38344     0            6      165.0        60.0  71.0    0.2    0.2    1.0
# 49984     0            7      170.0        75.0  86.0    1.0    1.0    1.0
# 32624     1           14      150.0        60.0  90.0    1.0    0.7    1.0
# 46437     1           11      150.0        70.0  90.0    0.6    0.6    1.0
# 35070     1            9      160.0        55.0  79.0    1.0    0.9    1.0
#
#        청력(우)  수축기혈압  ...  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  \
# 11841    1.0   99.0  ...     159.0  1.0      0.6        19.0        14.0
# 19602    1.0  106.0  ...     203.0  1.0      0.7        33.0        20.0
# 45519    1.0  131.0  ...      83.0  2.0      0.9        36.0        37.0
# 25747    1.0  117.0  ...     108.0  1.0      0.7        20.0        22.0
# 42642    1.0  150.0  ...      90.0  1.0      0.6        27.0        22.0
# ...      ...    ...  ...       ...  ...      ...         ...         ...
# 38344    1.0  125.0  ...     105.0  1.0      0.9        24.0        35.0
# 49984    1.0  123.0  ...      97.0  1.0      0.5        14.0        14.0
# 32624    1.0  139.0  ...      92.0  1.0      0.6        17.0        11.0
# 46437    1.0  138.0  ...     176.0  1.0      0.7        23.0        21.0
# 35070    1.0  116.0  ...     123.0  2.0      0.7        16.0         8.0
#
#        감마지티피  흡연상태  음주여부  음주여부예측      음주확률
# 11841   15.0   1.0     1       0  0.257466
# 19602   30.0   2.0     1       1  0.768329
# 45519   72.0   2.0     1       1  0.944292
# 25747   15.0   1.0     0       0  0.367734
# 42642   34.0   2.0     1       1  0.837821
# ...      ...   ...   ...     ...       ...
# 38344   28.0   1.0     1       1  0.535715
# 49984   17.0   2.0     0       1  0.671537
# 32624   20.0   2.0     0       0  0.219117
# 46437   33.0   1.0     1       0  0.432038
# 35070   12.0   1.0     1       0  0.426869
#
# [15000 rows x 24 columns]

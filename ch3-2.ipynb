# %% [markdown]
# # 실무예제 3-2

# %% [markdown]
# ## 다음은 2013년 전라남도 유망중소기업 지정업체 명단의 일부이다. 시군 속성과 지정구분 속성 간의 연관성 여부를 카이제곱 검정 방법에 의해 판단해 보시오. (단, 유의 수준은 0.05이다)

# %% [markdown]
# ### 데이터 파일 : ch3-2(유망중소기업현황).csv

# %% [markdown]
# ### 원본 투플수 : 386개

# %%
# ch3-2.py
import pandas as pd
import numpy as np
import cx_Oracle      # Oracle DB 연동을 위한 cx_Oracle 패키지 임포트

# 데이터로드 (ch2-2.csv : 데이터 원본 파일)
# encoding : 윈도우즈 환경에서의 한글 처리
# engine : python 3.6에서 한글이 포함된 파일이름 사용
rawData_org = pd.read_csv('.jupyter/ch3-2(유망중소기업현황).csv', encoding='CP949', engine='python')

# %%
rawData_org
# Out:
#       연번   시군  지정구분            기업명       대표자                   소  재  지  \
# 0      1  목포시  기술유망          브로드컴㈜       이봉헌    목포시 석현동 1175(벤처지원 202)
# 1      2  목포시  기술유망          ㈜케이에스       김시오             목포시 연산동1236-3
# 2      3  목포시  기술유망        삼진물산(주)       김관석            목포시 연산동 1239-1
# 3      4  목포시  기술유망            ㈜혜성       전재두             목포시 연산동1237-3
# 4      5  목포시  기술유망       (유)한국메이드       이승룡            목포시 연산동 1238-4
# 5      6  목포시  수출유망           환길산업       박승남            목포시 산정동 1780-1
# 6      7  목포시  수출유망          ㈜세광조선       유재억              목포시 연산동 1255
# 7      8  목포시  수출유망           선일물산       김태한           목포시 연산동 1236-11
# 8      9  목포시  기술유망       (유)메이드거금       이승룡        목포시 연산동 1291(삽진산단)
# 9     10  목포시  기술유망        맘키드크래프트       김명효    목포시 석현동 1175(문화지원 302)
# 10    11  목포시  기술유망      (유)신안산업개발       문용희          목포시 연산동 1237-10
# 11    12  목포시  기술유망      (주)젠트정보기술       김광진    목포시 석현동 1175(벤처지원 105)
# 12    13  목포시  기술유망      에스엠소프트웨어㈜       박영임    목포시 석현동 1175(벤처지원 204)
# 13    14  목포시  수출유망         ㈜맥스코리아       추봉식            목포시 연산동 1247-2
# 14    15  목포시  기술유망     (유)한국엔지니어링       김삼성        목포시 연산동 1294(삽진산단)
# 15    16  목포시  수출유망          ㈜대창식품       정현택           목포시 연산동 1236-15
# 16    17  목포시  기술유망       뉴21커뮤니티㈜       박선민  목포시 석현동 1175(문화지원센터 101)
# 17    18  목포시  지역특화       ㈜마스타마린조선       이경준              목포시 연산동 1280
# 18    19  목포시  기술유망          삼성마리너       김치형      목포시 연산동 1280-9(삽진산단)
# 19    20  목포시  기술유망    (주)휴먼아이티솔루션       최봉두      목포시 석현동 1175(벤처지원센터)
# 20    21  여수시  수출유망          오천산업㈜       조인순                여수 만흥동 8-4
# 21    22  여수시  기술유망        ㈜대경엠앤아이       김학태                여수 월하동 6-6
# 22    23  여수시  기술유망          재원산업㈜       심장섭              여수 낙포동 159-3
# 23    24  여수시  기술유망          유한기술㈜       장승혁               여수 중흥동 1480
# 24    25  여수시  기술유망         ㈜에스에프시  이정석\n홍정구   여수 화치동 국가산업단지11-04-0007
# 25    26  여수시  수출유망          영신수산㈜       김방심         여수 돌산읍 우두리 755-11
# 26    27  여수시  기술유망           ㈜피오씨       최병삼             여수 소호동 1198-7
# 27    28  여수시  기술유망       ㈜한국환경사업단       최영기              여수 월내동 324-4
# 28    29  여수시  기술유망        화성엔지니어링       김창규              여수 국동 37-144
# 29    30  여수시  지역특화      ㈜전라도백서방김치       백봉준                여수 만흥동 8-1
# ..   ...  ...   ...            ...       ...                       ...
# 356  357  장성군  기술유망      ㈜삼원 이.엔.지       전홍섭           장성군 북이면 신월리 122
# 357  358  장성군  지역특화       백양영농조합법인       차후덕         장성군 북이면 수성리 505-1
# 358  359  장성군  수출유망            ㈜창일       황대연           장성군 북일면 신흥리 502
# 359  360  장성군  기술유망           ㈜폼피아       박상혁         장성군 삼계면 부성리 789-2
# 360  361  장성군  기술유망          용호금속㈜       김용갑        장성군 황룡면 월평리 200-55
# 361  362  장성군  지역특화          ㈜광암스틸       조재희        장성군 동화면 남평리 1062-8
# 362  363  장성군  기술유망        대영스틸산업㈜       박정환           장성군 동화면 연산로 149
# 363  364  장성군  기술유망       (주)한맥캐미칼       최경관           장성군 황룡면 황룡로 177
# 364  365  장성군  수출유망       디와이엘엔제이㈜       김태수        장성군 동화면 남평리 1058-3
# 365  366  완도군  지역특화          제일산업㈜       정옥심         완두군완도읍 가용리 1089-9
# 366  367  완도군  기술유망         ㈜장보고물산       김태현             완도군완도읍가용리1088
# 367  368  완도군  기술유망           성원물산       강순례              완도군 완도죽청리983
# 368  369  완도군  수출유망          ㈜홍익산업       최종홍           완도군 군외면 불목리 464
# 369  370  완도군  기술유망         완도바다식품       이정업       완도군 완도읍 가용리 1088-15
# 370  371  완도군  수출유망  금일광선영어   조합법인       김말선               완도군 금일읍 충동리
# 371  372  완도군  기술유망          ㈜해신진미       민정국              완도군읍화흥리544-4
# 372  373  완도군  기술유망        ㈜해림후코이단       이지효      완도군 완도읍 가용리 1088-14
# 373  374  완도군  지역특화          ㈜향아식품       김월성        완도군 완도읍 가용리 1092-5
# 374  375  완도군  지역특화         ㈜청해진수산       이인환                 완도군완도읍대야리
# 375  376  완도군  기술유망           대진식품       오종대        완도군 완도읍 군내리 1237-6
# 376  377  완도군  기술유망           대라식품       김규수          완도군 완도읍 가용리 1030
# 377  378  완도군  기술유망       (주)청해레미콘       박병호       완도군 완도읍 대신리 1084-13
# 378  379  완도군  지역특화          ㈜흥일식품       김도환           완도군완도읍가용리1087-9
# 379  380  완도군  수출유망           한들수산       서순필           완도군 완도읍 죽청리 990
# 380  381  완도군  지역특화        (주)바다미소       천화성       완도군 완도읍 가용리 1087-10
# 381  382  완도군  지역특화          ㈜세영산업       김주효                완도군 완도읍가용리
# 382  383  완도군  기술유망         동주씨테크㈜       이용철        완도군 완도읍 가용리 1086-6
# 383  384  진도군  수출유망      대대로영농조합법인       김애란      진도군 군내면 명량대첩로 288-23
# 384  385  진도군  지역특화    진도정미소영농조합법인       이운갑           진도군 의신면 돈지리 144
# 385  386  신안군  기술유망        ㈜영진그린식품       호병용        신안군 지도읍 두류산길 91-41
#
#                          주생산품  전화번호(061) 비고\n(지정번호)
# 0                        정보통신   284-0017       11-1
# 1                       용접철망외  1588-4118       11-2
# 2                       참치통조림   270-6113       11-3
# 3                       가드레일외  1588-2811       11-4
# 4                        선박블록   278-4411       11-5
# 5                         해초류   272-7147       11-6
# 6                        강선건조   277-6111       11-7
# 7                         조미김   273-6750       11-8
# 8                        절  단   277-4418       11-9
# 9                      도자관광상품   287-1155      11-10
# 10                    수문,권양기종   245-5524      11-11
# 11                      소프트웨어   284-0045      11-12
# 12                     태양광솔루션   285-3411      11-13
# 13                   광고물부착방지물   272-5164      11-14
# 14                    선박엔진부품외   278-6777      11-15
# 15                         맛김   278-4426      11-16
# 16   홈페이지용역, 특산품판매(G-market등)  1644-9501       12-1
# 17                         보트   273-5778      12-53
# 18                      유압양망기   279-4900       13-1
# 19                  컴퓨터 프로그래밍   287-6633       13-2
# 20                 수산물\n건조가공품   651-9409      11-17
# 21                 설치용 \n금속탱크   686-0700      11-18
# 22                      유기화학물   690-9222      11-19
# 23                 증류기,\n열교환기   685-7550      11-20
# 24                      계면활성제   692-8300      11-21
# 25                 수산물\n냉동가공품   644-3030      11-22
# 26                기술용역,\n항만운송   652-6819      11-23
# 27                       화학제품   686-7066      11-24
# 28                  선박구성\n부분품   642-3530      11-25
# 29                      김치가공품   653-8859      11-26
# ..                        ...        ...        ...
# 356                      전동댐퍼   394-3577     11-270
# 357                      액상차류   392-7410     11-271
# 358                   pe pipe   394-8773      12-61
# 359                 가교발포폴리에텔렌   394-3811      12-62
# 360               소각로 및 자동차부품   392-3643      13-46
# 361                   금속선(보철)   393-6997      13-47
# 362                      강구조물   393-8660      13-48
# 363                    플라스틱시트   393-8141      13-49
# 364                    와이어하네스   392-9521      13-50
# 365                       건미역   554-5581     11-279
# 366                       조미김   555-2025     11-287
# 367                       조미김   554-0631     11-274
# 368                     톳, 미역   552-1955     11-277
# 369        천연조미료,해조국수,장전복,톳젤리   553-8899     11-288
# 370              미역귀,  다시마      553-9925     11-289
# 371                김,미역멸치.조미김   554-6502     11-282
# 372                      후코이단   554-9515     11-283
# 373                        미역   552-8989     11-278
# 374                      조미김류   554-6603     11-275
# 375                       조미김   554-5277     11-284
# 376                       조미김   554-6566     11-285
# 377                       레미콘   552-1144     11-281
# 378                 조미김,해산물가공    5548784     11-286
# 379                   마른김,김밥김   555-1959     11-280
# 380                       조미김   554-6020     11-273
# 381                    찐톳.건미역   555-0294     11-276
# 382               개량부자 전복양식자재   554-6690      12-63
# 383                        홍주   542-3399     11-290
# 384                 흑미, 기타유색미   544-3459      12-64
# 385               천일염\n기타 가공염   275-2330     11-291
#
# [386 rows x 9 columns]

# %%
# 원본 데이터파일에서 '시군'과 '지정구분' 속성만 추출
rawData = rawData_org.loc[:,'시군':'지정구분']

# %%
rawData
# Out:
#       시군  지정구분
# 0    목포시  기술유망
# 1    목포시  기술유망
# 2    목포시  기술유망
# 3    목포시  기술유망
# 4    목포시  기술유망
# 5    목포시  수출유망
# 6    목포시  수출유망
# 7    목포시  수출유망
# 8    목포시  기술유망
# 9    목포시  기술유망
# 10   목포시  기술유망
# 11   목포시  기술유망
# 12   목포시  기술유망
# 13   목포시  수출유망
# 14   목포시  기술유망
# 15   목포시  수출유망
# 16   목포시  기술유망
# 17   목포시  지역특화
# 18   목포시  기술유망
# 19   목포시  기술유망
# 20   여수시  수출유망
# 21   여수시  기술유망
# 22   여수시  기술유망
# 23   여수시  기술유망
# 24   여수시  기술유망
# 25   여수시  수출유망
# 26   여수시  기술유망
# 27   여수시  기술유망
# 28   여수시  기술유망
# 29   여수시  지역특화
# ..   ...   ...
# 356  장성군  기술유망
# 357  장성군  지역특화
# 358  장성군  수출유망
# 359  장성군  기술유망
# 360  장성군  기술유망
# 361  장성군  지역특화
# 362  장성군  기술유망
# 363  장성군  기술유망
# 364  장성군  수출유망
# 365  완도군  지역특화
# 366  완도군  기술유망
# 367  완도군  기술유망
# 368  완도군  수출유망
# 369  완도군  기술유망
# 370  완도군  수출유망
# 371  완도군  기술유망
# 372  완도군  기술유망
# 373  완도군  지역특화
# 374  완도군  지역특화
# 375  완도군  기술유망
# 376  완도군  기술유망
# 377  완도군  기술유망
# 378  완도군  지역특화
# 379  완도군  수출유망
# 380  완도군  지역특화
# 381  완도군  지역특화
# 382  완도군  기술유망
# 383  진도군  수출유망
# 384  진도군  지역특화
# 385  신안군  기술유망
#
# [386 rows x 2 columns]

# %%
# Oracle DB 연결
# 접속정보(connection string) : ID/PASS@CONNECTION_ALIAS
# CONNECTION_ALIAS : Oracle TNSNAMES.ORA 파일에 있는 접속정보 별칭(ALIAS)
conn_ora = cx_Oracle.connect("prep1/prep1@XE")

# DB 커서(Cursor) 선언
cur = conn_ora.cursor()

# 사용할 Oracle 소스 테이블명 지정
src_table = "d_base3_2"

# 데이터프레임(rawData)에 저장된 데이터를 Oracle 테이블(d_base3_2)에 입력하기 위한 로직
# d_base3_2 테이블 존재하는지 체크하는 함수
def table_exists(name=None, con=None):
    sql = "select table_name from user_tables where table_name='MYTABLE'".replace('MYTABLE', name.upper())
    df = pd.read_sql(sql, con)

    # 테이블이 존재하면 True, 그렇지 않으면 False 반환
    exists = True if len(df) > 0 else False
    return exists

# 테이블(d_base3_2) 생성 (테이블이 이미 존재한다면 TRUNCATE TABLE)
if table_exists(src_table, conn_ora):
    cur.execute("TRUNCATE TABLE " + src_table)
else:
    cur.execute("create table " + src_table + " ( \
               시군 varchar2(10), \
               지정구분 varchar2(20))")

# Sequence 구조를 Dictionary 구조((element, value))로 변환하는 함수
# 예: ("Matt", 1) -> {'1':'Matt', '2':1}
# INSERT INTO ... VALUES (:1, :2, ...) 에서 바인드 변수값을 주기위해 Dictionary item 구조 사용
def convertSequenceToDict(list):
    dict = {}
    argList = range(1, len(list) + 1)
    for k, v in zip(argList, list):
        dict[str(k)] = v
    return dict

# 데이터프레임에 저장된 데이터를 Oracle 테이블로 입력(insert)
cols = [k for k in rawData.dtypes.index]
colnames = ','.join(cols)
colpos = ', '.join([':' + str(i + 1) for i, f in enumerate(cols)])
insert_sql = 'INSERT INTO %s (%s) VALUES (%s)' % (src_table, colnames, colpos)

# INSERT INTO ... VALUES (:1, :2, ...)의 바인드 변수 값을 저장하는 Dictionary 구조 생성
data = [convertSequenceToDict(rec) for rec in rawData.values]

# 바인드 변수와 Dictionary 데이터구조를 활용하여 Bulk Insertion 구현
cur.executemany(insert_sql, data)
conn_ora.commit()

# %% [markdown]
# ### 실무예제 2-2의 Oracle 연동 설명 참조
# ### Oracle sqlplus를 통해서 d_base3_2 테이블 생성 확인

# %%
# 관측도수/기대도수 분할표 생성 (1차원 배열 형식)
count_df = pd.read_sql("select a.시군 \
                        , a.지정구분 \
                        , nvl(b.관측도수,0) 관측도수 /*관측되지않은 (시군+지정구분)은 0으로 처리*/ \
                        , a.기대도수_시군 * a.기대도수_지정구분 / a.기대도수_전체 기대도수 \
                      from ( \
                             select x.시군, y.지정구분 \
                                  , x.기대도수_시군 \
                                  , y.기대도수_지정구분 \
                                  , x.기대도수_전체 \
                             from ( select 시군 \
                                         , count(*) 기대도수_시군 /* 시군 속성의 cardinality */ \
                                         , sum(count(*)) over () 기대도수_전체 /* 전체 행 개수 */ \
                                    from " + src_table + " \
                                    group by 시군 ) x, \
                           ( select 지정구분 \
                                  , count(*) 기대도수_지정구분 /* 지정구분 속성의 cardinality */ \
                             from " + src_table + " \
                             group by 지정구분 ) y ) a, \
                           ( select 시군 \
                                  , 지정구분 \
                                  , count(*) 관측도수 /* 시군, 지정구분 별 실제 행 개수 */ \
                             from " + src_table + " \
                             group by 시군, 지정구분 ) b \
                      where a.시군 = b.시군(+) /* 특정 (시군+지정구분) 값은 존재하지 않을 수 \
                                                있어서 외부조인으로 처리 */ \
                           and a.지정구분 = b.지정구분(+)", con=conn_ora)

# %% [markdown]
# ### pandas 데이터프레임에 카이제곱 검정을 위한 관측도수/기대도수 분할표 저장
# ### ‘시군’ 속성 ‘지정구분’ 속성에 대한 관측도수와 기대도수를 구하기 위해서 Oracle SQL을 활용
# #### 관측도수 :  ‘시군’과 ‘지정구분’ 속성값의 조합에 대한 실제 출현횟수
# #### 기대도수 : 전체 행의 개수와 각 속성의 카디널러티(cardinality, 서로 다른 속성값의 개수)를 구하여 산출
# #### 실제 출현하지 않은 (시군+지정구분) 속성값도 포함시키기 위해서 외부조인(outer join)을 수행

# %%
# 관측도수/기대도수 분할표 출력
count_df
# Out:
#      시군  지정구분  관측도수       기대도수
# 0   목포시  기술유망    14  13.056995
# 1   나주시  수출유망     3   5.531088
# 2   보성군  수출유망     3   1.896373
# 3   보성군  지역특화     3   2.269430
# 4   해남군  지역특화     2   1.323834
# 5   무안군  수출유망     3   2.686528
# 6   무안군  기술유망     9  11.098446
# 7   영광군  지역특화     3   1.512953
# 8   완도군  기술유망     9  11.751295
# 9   신안군  기술유망     1   0.652850
# 10  여수시  기술유망    23  22.849741
# 11  영광군  수출유망     1   1.264249
# 12  목포시  지역특화     1   3.782383
# 13  여수시  수출유망     8   5.531088
# 14  순천시  기술유망    29  24.808290
# 15  순천시  수출유망     6   6.005181
# 16  순천시  지역특화     3   7.186528
# 17  나주시  지역특화    10   6.619171
# 18  광양시  기술유망    37  32.642487
# 19  화순군  기술유망    23  20.238342
# 20  강진군  지역특화     4   1.323834
# 21  영광군  기술유망     4   5.222798
# 22  완도군  수출유망     3   2.844560
# 23  광양시  지역특화     6   9.455959
# 24  담양군  기술유망    14  11.098446
# 25  구례군  지역특화     1   1.512953
# 26  화순군  수출유망     3   4.898964
# 27  장흥군  수출유망     1   0.948187
# 28  장성군  수출유망     2   3.002591
# 29  여수시  지역특화     4   6.619171
# ..  ...   ...   ...        ...
# 36  구례군  기술유망     6   5.222798
# 37  구례군  수출유망     1   1.264249
# 38  화순군  지역특화     5   5.862694
# 39  강진군  기술유망     2   4.569948
# 40  해남군  기술유망     4   4.569948
# 41  영암군  수출유망     6   5.373057
# 42  영암군  지역특화    12   6.430052
# 43  함평군  기술유망     6   5.875648
# 44  함평군  수출유망     3   1.422280
# 45  목포시  수출유망     5   3.160622
# 46  나주시  기술유망    22  22.849741
# 47  곡성군  기술유망     5   3.917098
# 48  고흥군  수출유망     1   0.948187
# 49  장흥군  기술유망     2   3.917098
# 50  해남군  수출유망     1   1.106218
# 51  영암군  기술유망    16  22.196891
# 52  장성군  기술유망    15  12.404145
# 53  진도군  수출유망     1   0.316062
# 54  진도군  지역특화     1   0.378238
# 55  광양시  수출유망     7   7.901554
# 56  담양군  지역특화     2   3.215026
# 57  곡성군  수출유망     1   0.948187
# 58  장흥군  지역특화     3   1.134715
# 59  완도군  지역특화     6   3.404145
# 60  함평군  지역특화     0   1.702073
# 61  신안군  지역특화     0   0.189119
# 62  고흥군  지역특화     0   1.134715
# 63  신안군  수출유망     0   0.158031
# 64  곡성군  지역특화     0   1.134715
# 65  진도군  기술유망     0   1.305699
#
# [66 rows x 4 columns]

# %%
# 2개 속성에 대한 자유도(degree of freedom) 갭 구하기
# A 속성에 대한 cardinality = a, B 속성에 대한 cardinality = b라 가정
# cardinality : 서로 다른 속성값의 개수
# 분할표 전체 행 갯수(a*b) 구하기
tot_rows = count_df.shape[0]

# %% [markdown]
# ### ‘시군’ 속성의 카디널러티(a) = 22
# ### ‘지정구분’ 속성의 카디널러티(b) = 3
# ### 그래서, (시군+지정구분) 속성조합의 카디널러티(a\*b) = 22 * 3 = 66

# %%
tot_rows  # 변수확인
# Out:
# 66

# %%
# A 속성의 cardianlity(a)와 B 속성의 cardinality(b) 구하기
count_df2 = pd.read_sql("select count(distinct 시군) 도수_시군 \
                           , count(distinct 지정구분) 도수_지정구분\
                      from " + src_table , con=conn_ora)

# %%
count_df2  # 변수확인
# Out:
#    도수_시군  도수_지정구분
# 0     22        3

# %%
# cardinality 갭 [(a*b-1) - (a-1)*(b-1)] 구하기
v_ddof = (tot_rows - 1) - (count_df2['도수_시군']-1)*(count_df2['도수_지정구분']-1)

# %% [markdown]
# ### 속성조합의 자유도(degree of freedom) = (66-1) = 65
# ### 실제 자유도는 (22-1) * (3-1) = 42
# ### 위 두 값의 차이 : 23 -> chisquare() 함수의 세번째 패러미터로 사용

# %%
v_ddof  # 변수확인
# Out:
# 0    23
# dtype: int64

# %%
obs_array = count_df['관측도수'] # obs_array : 관측도수를 저장하는 1차원 배열

# %% [markdown]
# ### obs_array : chisquare() 함수의 첫번째 패러미터로 사용

# %%
obs_array  # 변수확인
# Out:
# 0     14
# 1      3
# 2      3
# 3      3
# 4      2
# 5      3
# 6      9
# 7      3
# 8      9
# 9      1
# 10    23
# 11     1
# 12     1
# 13     8
# 14    29
# 15     6
# 16     3
# 17    10
# 18    37
# 19    23
# 20     4
# 21     4
# 22     3
# 23     6
# 24    14
# 25     1
# 26     3
# 27     1
# 28     2
# 29     4
#       ..
# 36     6
# 37     1
# 38     5
# 39     2
# 40     4
# 41     6
# 42    12
# 43     6
# 44     3
# 45     5
# 46    22
# 47     5
# 48     1
# 49     2
# 50     1
# 51    16
# 52    15
# 53     1
# 54     1
# 55     7
# 56     2
# 57     1
# 58     3
# 59     6
# 60     0
# 61     0
# 62     0
# 63     0
# 64     0
# 65     0
# Name: 관측도수, Length: 66, dtype: int64

# %%
exp_array = count_df['기대도수'] # exp_array : 기대도수를 저장하는 1차원 배열

# %% [markdown]
# ### exp_array : chisquare() 함수의 두번째 패러미터로 사용

# %%
exp_array  # 변수확인
# Out:
# 0     13.056995
# 1      5.531088
# 2      1.896373
# 3      2.269430
# 4      1.323834
# 5      2.686528
# 6     11.098446
# 7      1.512953
# 8     11.751295
# 9      0.652850
# 10    22.849741
# 11     1.264249
# 12     3.782383
# 13     5.531088
# 14    24.808290
# 15     6.005181
# 16     7.186528
# 17     6.619171
# 18    32.642487
# 19    20.238342
# 20     1.323834
# 21     5.222798
# 22     2.844560
# 23     9.455959
# 24    11.098446
# 25     1.512953
# 26     4.898964
# 27     0.948187
# 28     3.002591
# 29     6.619171
#         ...
# 36     5.222798
# 37     1.264249
# 38     5.862694
# 39     4.569948
# 40     4.569948
# 41     5.373057
# 42     6.430052
# 43     5.875648
# 44     1.422280
# 45     3.160622
# 46    22.849741
# 47     3.917098
# 48     0.948187
# 49     3.917098
# 50     1.106218
# 51    22.196891
# 52    12.404145
# 53     0.316062
# 54     0.378238
# 55     7.901554
# 56     3.215026
# 57     0.948187
# 58     1.134715
# 59     3.404145
# 60     1.702073
# 61     0.189119
# 62     1.134715
# 63     0.158031
# 64     1.134715
# 65     1.305699
# Name: 기대도수, Length: 66, dtype: float64

# %%
# 카이제곱검정을 위한 scipy 패키지 중 stats 모듈 임포트
from scipy import stats

# %%
# stats.chisquare() : 카이제곱검정 함수
chis = stats.chisquare(obs_array, exp_array, ddof=v_ddof)

# %% [markdown]
# ### chisquare() 함수 : 카이제곱(χ2) 통계량을 산출하는 함수
# #### 첫번째 패러미터 : 1차원 배열 형태의 관측도수 리스트
# #### 두번째 패러미터 : 1차원 배열 형태의 기대도수 리스트
# #### 세번째 패러미터 : 자유도 차이 [(a\*b-1) - (a-1)\*(b-1)]

# %%
# stats.chisquare() 수행 후의 카이제곱 통계량과 p-value
print("statistic = %.3f, p-value = %.5f" % (chis))
# Out:
# statistic = 54.544, p-value = 0.09287

# %% [markdown]
# ### 카이제곱 통계량(statistic) : 54.544
# ### 유의확률(p-value) : 0.09287
# ### 유의확률이 유의수준 0.05로 설정한다면 귀무가설(두 속성은 연관성이 없다)이 채택됨. 결론적으로, 시군과 지정구분 사이에는 큰 연관성은 없는 것으로 판단할 수 있음.

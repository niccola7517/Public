# %% [markdown]
# # 실무예제 3-1

# %% [markdown]
# ## 다음은 2013년 전국 주요지점별 유동인구 수 현황의 일부이다. 남자20대 vs. 여자20대, 남자10대 vs. 여자50대의 상관계수를 구하여 비교해 보고, 중복 속성으로 판단할 수 있을지 검토해 보시오.

# %% [markdown]
# ### 데이터 파일 : ch3-1(유동인구수).csv

# %% [markdown]
# ### 원본 투플수 : 23,221개

# %%
# ch3-1.py
import pandas as pd
import numpy as np

# matplotlib : 자료를 차트(chart)나 플롯(plot)으로 시각화(visulaization)하는 패키지
# pyplot : matlab이라는 수치해석 소프트웨어의 시각화 명령을 거의 그대로 사용할 수 있도록 
#          Matplotlib 의 하위 API를 포장(wrapping)한 명령어 집합을 제공
import matplotlib.pyplot as plt

# 데이터로드 (ch3-1.csv : 데이터 원본 파일)
# encoding : 윈도우즈 환경에서의 한글 처리
# engine : python 3.6에서 한글이 포함된 파일이름 사용
rawData = pd.read_csv('.jupyter/ch3-1(유동인구수).csv', encoding='CP949', engine='python')

# %%
rawData
# Out:
#              조사일자        시간대     X좌표     Y좌표            행정구역명  남자10대  남자20대  \
# 0      2010-06-21  12시~13시까지  343099  417482     대전광역시 서구 월평동      2     24
# 1      2010-06-21  19시~20시까지  343099  417482     대전광역시 서구 월평동     19     44
# 2      2010-06-20  12시~13시까지  343099  417482     대전광역시 서구 월평동     13     33
# 3      2010-06-20  19시~20시까지  343099  417482     대전광역시 서구 월평동     23     33
# 4      2010-06-21  12시~13시까지  343121  417343     대전광역시 서구 월평동      0      9
# 5      2010-06-21  19시~20시까지  343121  417343     대전광역시 서구 월평동      4     22
# 6      2010-06-20  12시~13시까지  343121  417343     대전광역시 서구 월평동      3      8
# 7      2010-06-20  19시~20시까지  343121  417343     대전광역시 서구 월평동      6     17
# 8      2010-06-04  12시~13시까지  311013  523508     경기도 수원시 정자1동     24     26
# 9      2010-06-04  19시~20시까지  311013  523508     경기도 수원시 정자1동     13     36
# 10     2010-06-05  12시~13시까지  311013  523508     경기도 수원시 정자1동     14     25
# 11     2010-06-05  19시~20시까지  311013  523508     경기도 수원시 정자1동     36     42
# 12     2010-06-24  12시~13시까지  343529  417164     대전광역시 서구 갈마동      6     10
# 13     2010-06-24  19시~20시까지  343529  417164     대전광역시 서구 갈마동     30     19
# 14     2010-06-26  12시~13시까지  343529  417164     대전광역시 서구 갈마동     11      7
# 15     2010-06-26  19시~20시까지  343529  417164     대전광역시 서구 갈마동      9     27
# 16     2010-06-24  12시~13시까지  343463  417150     대전광역시 서구 갈마동      3      8
# 17     2010-06-24  19시~20시까지  343463  417150     대전광역시 서구 갈마동     23     25
# 18     2010-06-26  12시~13시까지  343463  417150     대전광역시 서구 갈마동      3      7
# 19     2010-06-26  19시~20시까지  343463  417150     대전광역시 서구 갈마동     15     14
# 20     2010-06-27  12시~13시까지  344808  416386     대전광역시 서구 탄방동      8      8
# 21     2010-06-27  19시~20시까지  344808  416386     대전광역시 서구 탄방동      8     14
# 22     2010-06-27  12시~13시까지  344797  416293     대전광역시 서구 탄방동      4      5
# 23     2010-06-27  19시~20시까지  344797  416293     대전광역시 서구 탄방동      1     19
# 24     2010-06-28  12시~13시까지  348993  427864    대전광역시 대덕구 석봉동     30     17
# 25     2010-06-28  19시~20시까지  348993  427864    대전광역시 대덕구 석봉동     11     26
# 26     2010-06-26  12시~13시까지  348993  427864    대전광역시 대덕구 석봉동     13     23
# 27     2010-06-26  19시~20시까지  348993  427864    대전광역시 대덕구 석봉동     38     58
# 17        18     24     50     16     49     53     41     28
# 18        12     19     26     13     25     23     23     14
# 19         8     18     28      9     23     20     18      6
# 20         8      5      9     12     14      7     10      2
# 21        18      5      7      6     33     17     12     14
# 22         8      6      5      0     11      7      4      9
# 23         4      5      4      0      9      8      4      6
# 24        11      3     15     23     11      5      9     35
# 25        13     14     27     41     16     15      6     35
# 26        54     12     31      7     35     28     42     59
# 27        29     48     33     27     42     34     12      8
# 28        27     12     10     15     27     38     53     22
# 29        30     31     12     16     54     18     11     47
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# 23191     72     80    104     88     60     64    140     80
# 23192     84    120     92     96     76    108     84    144
# 23193     12     19     36      9     27     15     17     31
# 23194     14     16     35     11     29     17     17     34
# 23195     15     17     11      3      9      6     12     10
# 23196     12     13     16      7     11     15     17     12
# 23197     36     44     72     48     24     76     80    116
# 23198     80     68    112     68    120    124    120    132
# 23199     36     40     84     32     36     36     36     88
# 23200     40     40     64     48     24     48     52    104
# 23201     36     44     64     16     40     68     54     88
# 23202     68     54     88     24     60    120     72     84
# 23203     36     32     54     44     24     44     32     64
# 23204     52     52     58     20     40     44     48     92
# 23205     45     50     36     49     32     88     76     44
# 23206     62     43     31     56     51     42     82     24
# 23207     77     60     19     65     47     87     60     45
# 23208     71     46     24     53     54     74     89     39
# 23209     75     64     30     28     40     97     75     38
# 23210     46     48     29     23     25     92     85     28
# 23211     76     71     40     49     26     88     90     62
# 23212     84     59     29     35     36     67     73     21
# 23213     30     28     17      8     38     30     20     13
# 23214     54     46     25     21     65     36     27     18
# 23215     35     32     20     13     32     40     26     10
# 23216     60     56     26     22     45     34     25     15
# 23217     22     35     40      8     15     33     25     42
# 23218     29     23     55     31     17     37     19     45
# 23219     35     31     45     10     12     31     25     37
# 23220     32     27     42     12     18     29     31     43
#
# [23221 rows x 15 columns]

# %%
# 상관계수 분석 (남자20대 vs. 여자20대)
corr = np.corrcoef(rawData['남자20대'], rawData['여자20대'])

# %% [markdown]
# ### np.corrcoef() : 인수로 사용된 두 속성 간의 상관계수를 구하는 numpy 패키지 함수

# %%
print("-- 상관계수(남자20대 vs. 여자20대) --")
print(corr)
# Out:
# -- 상관계수(남자20대 vs. 여자20대) --
# [[1.         0.84727982]
#  [0.84727982 1.        ]]

# %% [markdown]
# ### 남자20대와 여자20대의 상관계수는 0.84 이상으로 두 속성 사이에는 강한 양의 상관관계가 존재
# ### -> 남자20대와 여자20대을 중복 속성으로 판단하여 하나의 속성을 분석 대상에서 제외해도 전체적인 분석결과에는 큰 영향을 미치지 않을 것으로 추정할 수 있음

# %%
plt.figure(figsize  = (8,6))  # 차트 사이즈 설정 (inch 단위)

# scatter() : 산점도(scatter plot)를 그려주는 함수
plt.scatter(rawData['남자20대'], rawData['여자20대'])

plt.show()  # 차트 보여주기

# %% [markdown]
# ### figure() : 차트 환경을 설정하는 matplotlib.pyplot 패키지 함수
# ### scatter() : 산점도 차트를 그리는 함수
# ### show() : 차트를 화면에 출력하는 함수

# %%
# 상관계수 분석 (남자10대 vs. 여자50대)
corr = np.corrcoef(rawData['남자10대'], rawData['여자50대'])
print("-- 상관계수(남자10대 vs. 여자50대) --")
print(corr)

plt.figure(figsize  = (8,6))
plt.scatter(rawData['남자10대'], rawData['여자50대'])
plt.show()
# Out:
# -- 상관계수(남자10대 vs. 여자50대) --
# [[1.         0.26322329]
#  [0.26322329 1.        ]]

# %% [markdown]
# ### 남자10대와 여자50대의 상관계수는 0.26 정도로 두 속성 사이의 상관관계는 약한 양의 상관관계로 볼 수 있음

# %%
# ch4-2.py
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(module='sklearn*', action='ignore', category=DeprecationWarning)

# %%
# 데이터로드 (ch4-2(붓꽃데이터).csv : 데이터 원본 파일)
# encoding : 윈도우즈 환경에서의 한글 처리
# engine : python 3.6에서 한글이 포함된 파일이름 사용
rawData_org = pd.read_csv('datasets/국민건강정보/NHIS_OPEN_GJ_2017.csv', encoding='CP949', engine='python')

# %%
# 원본데이터의 튜플 수와 컬럼수 출력
rawData_org.shape
# Out:
# (1000000, 34)

# %%
# 의사결정트리에 사용할 속성리스트
feature_columns_to_use = ['성별코드', '연령대코드(5세단위)', '신장(5Cm단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)',
                    '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)', '트리글리세라이드', 'HDL콜레스테롤',
                    'LDL콜레스테롤', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '음주여부']

rawData = rawData_org[feature_columns_to_use]

# %%
# 속성값이 NULL인 튜플 제외
rawData = rawData.dropna()

# 인덱스 재설정
rawData.reset_index(inplace=True, drop=True)

# 원본데이터의 튜플 수와 컬럼수 출력
rawData.shape
# Out:
# (990910, 22)

# %%
import random as rd  # 샘플링을 위한 random 패키지 임포트

# 1) 샘플링을 통한 수량 축소
# 원본데이터 중 50,000개를 튜플만 샘플링
# len() : 데이터프레임의 크기를 구하는 함수
sample_idx = rd.sample(range(0, len(rawData)), 50000)

# 인덱스 값 정렬(오름차순)
sample_idx.sort()

sample_idx
# Out:
# [3,
#  32,
#  53,
#  96,
#  111,
#  116,
#  161,
#  172,
#  173,
#  179,
#  188,
#  230,
#  238,
#  265,
#  313,
#  314,
#  328,
#  341,
#  379,
#  388,
#  423,
#  432,
#  438,
#  450,
#  465,
#  467,
#  487,
#  496,
#  524,
#  528,
#  532,
#  534,
#  558,
#  580,
#  589,
#  600,
#  631,
#  638,
#  645,
#  656,
#  691,
#  751,
#  765,
#  795,
#  820,
#  835,
#  894,
#  895,
#  903,
#  926,
#  934,
#  941,
#  961,
#  1009,
#  1029,
#  1035,
#  1050,
#  1092,
#  1096,
#  1113,
#  1114,
#  1120,
#  1128,
#  1146,
#  1158,
#  1168,
#  1184,
#  1204,
#  1227,
#  1232,
#  1237,
#  1243,
#  1248,
#  1263,
#  1284,
#  1291,
#  1356,
#  1366,
#  1392,
#  1428,
#  1436,
#  1440,
#  1443,
#  1456,
#  1530,
#  1557,
#  1565,
#  1582,
#  1604,
#  1618,
#  1630,
#  1741,
#  1758,
#  1764,
#  1768,
#  1773,
#  1783,
#  1789,
#  1863,
#  1870,
#  1927,
#  1935,
#  1950,
#  1993,
#  2014,
#  2051,
#  2107,
#  2126,
#  2157,
#  2181,
#  2203,
#  2230,
#  2231,
#  2258,
#  2313,
#  2346,
#  2347,
#  2375,
#  2382,
#  2427,
#  2495,
#  2496,
#  2520,
#  2569,
#  2570,
#  2572,
#  2574,
#  2583,
#  2590,
#  2593,
#  2595,
#  2602,
#  2637,
#  2648,
#  2710,
#  2716,
#  2735,
#  2830,
#  2837,
#  2850,
#  2855,
#  2865,
#  2906,
#  2910,
#  2919,
#  3007,
#  3036,
#  3039,
#  3054,
#  3064,
#  3075,
#  3098,
#  3107,
#  3108,
#  3144,
#  3151,
#  3195,
#  3240,
#  3248,
#  3262,
#  3266,
#  3279,
#  3287,
#  3302,
#  3370,
#  3375,
#  3379,
#  3383,
#  3405,
#  3441,
#  3521,
#  3544,
#  3551,
#  3573,
#  3582,
#  3583,
#  3599,
#  3622,
#  3624,
#  3684,
#  3695,
#  3702,
#  3732,
#  3746,
#  3752,
#  3767,
#  3769,
#  3805,
#  3816,
#  3821,
#  3829,
#  3843,
#  3867,
#  3869,
#  3880,
#  3912,
#  3914,
#  3936,
#  3966,
#  3983,
#  4027,
#  4062,
#  4063,
#  4077,
#  4109,
#  4126,
#  4129,
#  4154,
#  4157,
#  4162,
#  4164,
#  4180,
#  4209,
#  4219,
#  4247,
#  4253,
#  4257,
#  4259,
#  4262,
#  4286,
#  4289,
#  4323,
#  4430,
#  4437,
#  4481,
#  4516,
#  4520,
#  4525,
#  4529,
#  4558,
#  4574,
#  4590,
#  4601,
#  4625,
#  4645,
#  4650,
#  4669,
#  4673,
#  4694,
#  4696,
#  4698,
#  4737,
#  4763,
#  4775,
#  4784,
#  4788,
#  4810,
#  4812,
#  4820,
#  4843,
#  4876,
#  4890,
#  4903,
#  4907,
#  4909,
#  4915,
#  4948,
#  4968,
#  4996,
#  5002,
#  5042,
#  5043,
#  5067,
#  5077,
#  5101,
#  5107,
#  5109,
#  5114,
#  5124,
#  5131,
#  5158,
#  5161,
#  5174,
#  5187,
#  5188,
#  5190,
#  5198,
#  5200,
#  5240,
#  5243,
#  5258,
#  5289,
#  5305,
#  5313,
#  5338,
#  5373,
#  5385,
#  5393,
#  5405,
#  5418,
#  5420,
#  5466,
#  5519,
#  5538,
#  5539,
#  5547,
#  5549,
#  5571,
#  5610,
#  5627,
#  5629,
#  5656,
#  5701,
#  5721,
#  5728,
#  5741,
#  5762,
#  5770,
#  5773,
#  5784,
#  5811,
#  5856,
#  5873,
#  5874,
#  5879,
#  5918,
#  5935,
#  5945,
#  5955,
#  5982,
#  6008,
#  6021,
#  6025,
#  6107,
#  6111,
#  6114,
#  6148,
#  6149,
#  6176,
#  6181,
#  6185,
#  6202,
#  6215,
#  6223,
#  6235,
#  6252,
#  6256,
#  6292,
#  6294,
#  6321,
#  6379,
#  6385,
#  6415,
#  6418,
#  6422,
#  6431,
#  6433,
#  6437,
#  6454,
#  6456,
#  6505,
#  6507,
#  6556,
#  6592,
#  6594,
#  6605,
#  6614,
#  6638,
#  6656,
#  6661,
#  6667,
#  6733,
#  6745,
#  6764,
#  6787,
#  6819,
#  6824,
#  6828,
#  6837,
#  6847,
#  6865,
#  6872,
#  6907,
#  6922,
#  6923,
#  6927,
#  6983,
#  7019,
#  7039,
#  7072,
#  7133,
#  7138,
#  7168,
#  7183,
#  7205,
#  7206,
#  7267,
#  7270,
#  7287,
#  7293,
#  7300,
#  7301,
#  7333,
#  7340,
#  7374,
#  7416,
#  7445,
#  7477,
#  7483,
#  7513,
#  7543,
#  7545,
#  7573,
#  7577,
#  7586,
#  7588,
#  7604,
#  7644,
#  7661,
#  7663,
#  7693,
#  7765,
#  7768,
#  7787,
#  7791,
#  7810,
#  7814,
#  7831,
#  17684,
#  17696,
#  17709,
#  17820,
#  17843,
#  17859,
#  17882,
#  17891,
#  17917,
#  17935,
#  17936,
#  17976,
#  17994,
#  18005,
#  18016,
#  18019,
#  18022,
#  18058,
#  18064,
#  18065,
#  18078,
#  18081,
#  18085,
#  18106,
#  18110,
#  18112,
#  18143,
#  18149,
#  18176,
#  18254,
#  18270,
#  18273,
#  18276,
#  18308,
#  18310,
#  18327,
#  18349,
#  18356,
#  18364,
#  18369,
#  18370,
#  18378,
#  18380,
#  18382,
#  18454,
#  18460,
#  18479,
#  18503,
#  18512,
#  18542,
#  18545,
#  18555,
#  18574,
#  ...]

# %%
# 샘플링 된 인덱스로 구성된 샘플 데이터프레임 생성
rawData_sample = rawData.loc[sample_idx]

rawData_sample.reset_index(inplace=True, drop=True) #  인덱스 재설정

# 첫 10개의 행만 출력
rawData_sample.head(10)
# Out:
#    성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0     2           12      155.0        55.0  67.5    0.9    1.0    1.0    1.0
# 1     1            9      165.0        60.0  81.0    1.5    1.5    1.0    1.0
# 2     2           10      160.0        60.0  80.0    0.7    0.8    1.0    1.0
# 3     2            7      175.0        65.0  80.0    1.0    1.0    1.0    1.0
# 4     1           12      165.0        75.0  84.0    0.7    1.0    1.0    1.0
# 5     1            9      175.0        85.0  93.0    1.5    1.5    1.0    1.0
# 6     1           12      165.0        55.0  73.5    1.2    1.2    1.0    1.0
# 7     1            7      170.0        65.0  76.1    0.5    0.7    1.0    1.0
# 8     1            6      170.0        70.0  86.0    1.5    2.0    1.0    1.0
# 9     2            9      160.0        75.0  96.0    0.7    1.0    1.0    1.0
#
#    수축기혈압  ...   트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0  138.0  ...       97.0      52.0      88.0  1.0      0.6        21.0
# 1  134.0  ...      168.0      62.0     133.0  1.0      0.9        30.0
# 2  120.0  ...      105.0      62.0      86.0  1.0      0.9        17.0
# 3  130.0  ...       92.0      66.0      94.0  1.0      0.6        13.0
# 4  114.0  ...      144.0      46.0     107.0  1.0      0.8        43.0
# 5  128.0  ...      268.0      54.0     141.0  1.0      1.2        24.0
# 6  125.0  ...      146.0      50.0     143.0  1.0      1.1        26.0
# 7  102.0  ...       50.0      54.0      83.0  1.0      1.0        25.0
# 8  118.0  ...       69.0      57.0     119.0  1.0      0.9        38.0
# 9  176.0  ...       44.0      69.0     116.0  1.0      0.9        52.0
#
#    (혈청지오티)ALT  감마지티피  흡연상태  음주여부
# 0        24.0   30.0   1.0   1.0
# 1        27.0   80.0   3.0   1.0
# 2        11.0   13.0   1.0   0.0
# 3        16.0   18.0   1.0   0.0
# 4        55.0   25.0   1.0   0.0
# 5        28.0   28.0   2.0   1.0
# 6        17.0   24.0   3.0   0.0
# 7        20.0   17.0   1.0   1.0
# 8        57.0   24.0   2.0   1.0
# 9        69.0   29.0   2.0   1.0
#
# [10 rows x 22 columns]

# %%
rawData_sample.shape
# Out:
# (50000, 22)

# %%
# nonnumeric 속성을 categrical 데이터로 변환
nonnumeric_columns = ['성별코드','음주여부']

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in nonnumeric_columns:
    rawData_sample[feature] = le.fit_transform(rawData_sample[feature])

# %%
# 소스 데이터프레임에서 분류(classification)을 위한 속성 집합
X = rawData_sample.loc[:, feature_columns_to_use[:-1]]  
y = rawData_sample.loc[:, '음주여부']  # 분류 클래스(class)

from sklearn.model_selection import train_test_split  # 분석모형 선택에 관련된 모듈
    
# 자동으로 데이터셋을 트레이닝셋과 테스트셋으로 분리해주는 함수로
# 트레이닝셋과 데이터셋의 비율을 7:3으로 세팅함
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Scikit-Learn 패키지 : 머신 러닝 교육 및 실무를 위한 패키지로 샘플 데이터셋,
# 다양한 기계학습 기법에 대한 함수 등을 포함하고 있음
from sklearn.ensemble import RandomForestClassifier  # 랜덤포리스트 기법에 관련된 모듈

# DecisionTreeClassifier() : 의사결정트리를 생성하는 함수
random_forest = RandomForestClassifier(n_estimators=20, random_state=0)
random_forest
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# fit() : 트레이닝 데이터셋을 대상으로 의사결정트리 학습 진행
random_forest.fit(X_train, y_train)

# tree.predict() 함수를 활용하여 의사결정트리를 대상으로 테스트셋을 예측
y_pred_tr = random_forest.predict(X_test)

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(random_forest.score(X_train, y_train)))
print("Test Set Score1 : {:.2f}".format(random_forest.score(X_test, y_test)))
# Out:
# Train Set Score1 : 1.00
# Test Set Score1 : 0.71

# %%
from sklearn.metrics import accuracy_score  # 분류 정확도(classification accuracy)를 계산하는 모듈

# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.71

# %%
# RFE(Recursive Feature Elimination)
from sklearn.feature_selection import RFE

select = RFE(RandomForestClassifier(n_estimators=20, random_state=0), n_features_to_select = 10)
select.fit(X_train, y_train)
select
# Out:
# RFE(estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=0, verbose=0, warm_start=False),
#   n_features_to_select=10, step=1, verbose=0)

# %%
X_train_RFE = select.transform(X_train)
X_test_RFE = select.transform(X_test)
random_forest.fit(X_train_RFE, y_train)

y_pred_tr = random_forest.predict(X_test_RFE)

# %%
# 속성(feature) 별 중요도를 저장하는 데이터프레임 생성 
sel_feature = pd.DataFrame({'중요도' : select.ranking_}, index = feature_columns_to_use[:-1])

# 중요도의 내림차순으로 정렬
sel_feature.sort_values(by='중요도', ascending=False)
# Out:
#              중요도
# 청력(좌)         12
# 청력(우)         11
# 요단백           10
# 시력(좌)          9
# 혈청크레아티닌        8
# 시력(우)          7
# 성별코드           6
# 체중(5Kg 단위)     5
# 이완기혈압          4
# (혈청지오티)AST     3
# 흡연상태           2
# 수축기혈압          1
# 연령대코드(5세단위)    1
# 식전혈당(공복혈당)     1
# 트리글리세라이드       1
# HDL콜레스테롤       1
# LDL콜레스테롤       1
# 허리둘레           1
# 신장(5Cm단위)      1
# (혈청지오티)ALT     1
# 감마지티피          1

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(random_forest.score(X_train_RFE, y_train)))
print("Test Set Score1 : {:.2f}".format(random_forest.score(X_test_RFE, y_test)))
# Out:
# Train Set Score1 : 1.00
# Test Set Score1 : 0.70

# %%
# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.70
